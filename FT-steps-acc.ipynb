# %% [markdown]
# ## NPB-openACC-C-FT Implementation
# In this self-paced, hands-on lab, we will briefly explore some methods for OpenACC
#
# Qichao Hong

# %% [markdown]
# ---
# Before we begin, let's verify [WebSockets](http://en.wikipedia.org/wiki/WebSocket) are working on your system.  To do this, execute the cell block below by giving it focus (clicking on it with your mouse), and hitting Ctrl-Enter, or pressing the play button in the toolbar above.  If all goes well, you should see get some output returned below the grey cell.  If not, please consult the [Self-paced Lab Troubleshooting FAQ](https://developer.nvidia.com/self-paced-labs-faq#Troubleshooting) to debug the issue.

# %%
print ("The answer should be three: " + str(1+2))
# Out:
# The answer should be three: 3

# %% [markdown]
# First, run the cell below to get some info about the GPUs on the server.

# %%
# !nvidia-smi
# Out:
# Tue May 23 08:35:23 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.51                 Driver Version: 375.51                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 780 Ti  Off  | 0000:01:00.0     N/A |                  N/A |
# | 26%   39C    P8    N/A /  N/A |    346MiB /  3017MiB |     N/A      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 780 Ti  Off  | 0000:02:00.0     N/A |                  N/A |
# | 26%   39C    P8    N/A /  N/A |      1MiB /  3020MiB |     N/A      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |    0                  Not Supported                                         |
# |    1                  Not Supported                                         |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# CPU: Intel i7-4960x

# %% [markdown]
# ---
# <p class="hint_trigger">If you have never before taken an IPython Notebook based self-paced lab from NVIDIA, click this green box.
#       <div class="toggle_container"><div class="input_area box-flex1"><div class=\"highlight\">The following video will explain the infrastructure we are using for this self-paced lab, as well as give some tips on it's usage.  If you've never taken a lab on this system before, it's highly encourage you watch this short video first.<br><br>
# <div align="center"><iframe width="640" height="390" src="http://www.youtube.com/embed/ZMrDaLSFqpY" frameborder="0" allowfullscreen></iframe></div>
# <br>
# <h2 style="text-align:center;color:red;">Attention Firefox Users</h2><div style="text-align:center; margin: 0px 25px 0px 25px;">There is a bug with Firefox related to setting focus in any text editors embedded in this lab. Even though the cursor may be blinking in the text editor, focus for the keyboard may not be there, and any keys you press may be applying to the previously selected cell.  To work around this issue, you'll need to first click in the margin of the browser window (where there are no cells) and then in the text editor.  Sorry for this inconvenience, we're working on getting this fixed.</div></div></div></div></p>

# %% [markdown]
# ## Introduction to OpenACC
#
# Open-specification OpenACC directives are a straightforward way to accelerate existing Fortran and C applications. With OpenACC directives, you provide hints via compiler directives (or 'pragmas') to tell the compiler where -- and how -- it should parallelize compute-intensive code for execution on an accelerator.
#
# If you've done parallel programming using OpenMP, OpenACC is very similar: using directives, applications can be parallelized *incrementally*, with little or no change to the Fortran, C or C++ source. Debugging and code maintenance are easier. OpenACC directives are designed for *portability* across operating systems, host CPUs, and accelerators. You can use OpenACC directives with GPU accelerated libraries, explicit parallel programming languages (e.g., CUDA), MPI, and OpenMP, *all in the same program.*
#
# Watch the following short video introduction to OpenACC:
#
# <div align="center"><iframe width="640" height="390" style="margin: 0 auto;" src="http://www.youtube.com/embed/c9WYCFEt_Uo" frameborder="0" allowfullscreen></iframe></div>
#
# This hands-on lab walks you through a short sample of a scientific code, and demonstrates how you can employ OpenACC directives using a four-step process. You will make modifications to a simple C program, then compile and execute the newly enhanced code in each step. Along the way, hints and solution are provided, so you can check your work, or take a peek if you get lost.
#
# If you are confused now, or at any point in this lab, you can consult the <a href="#FAQ">FAQ</a> located at the bottom of this page.

# %% [markdown]
# # Step 1 - Characterize Your Application

# %% [markdown]
# The most difficult part of accelerator programming begins before the first line of code is written. If your program is not highly parallel, an accelerator or coprocesor won't be much use. Understanding the code structure is crucial if you are going to *identify opportunities* and *successfully* parallelize a piece of code. The first step in OpenACC programming then is to *characterize the application*. This includes:
#
# + benchmarking the single-thread, CPU-only version of the application
# + understanding the program structure and how data is passed through the call tree
# + profiling the application and identifying computationally-intense "hot spots"
#     + which loop nests dominate the runtime?
#     + what are the minimum/average/maximum tripcounts through these loop nests?
#     + are the loop nests suitable for an accelerator?
# + insuring that the algorithms you are considering for acceleration are *safely* parallel
#
# Note: what we've just said may sound a little scary, so please note that as parallel programming methods go OpenACC is really pretty friendly: think of it as a sandbox you can play in. Because OpenACC directives are incremental, you can add one or two directives at a time and see how things work: the compiler provides a *lot* of feedback. The right software plus good tools plus educational experiences like this one should put you on the path to successfully accelerating your programs.

# %% [markdown]
# ## Step 1 Profiling and Benchmarking
#
# Before you start modifying code and adding OpenACC directives, you should benchmark the serial version of the program. To facilitate benchmarking after this and every other step in our parallel porting effort, we have built a timing routine around the main structure of our program -- a process we recommend you follow in your own efforts. Let's run the `FT` file without making any changes -- and see how fast the serial program executes. This will establish a baseline for future comparisons.  Execute the following two cells to compile and run the program.

# %%
# !cd ./NPB-acc/FT-seq/NPB3.3-SER-C/ && make veryclean && make FT CLASS=A
# Out:
# rm -f core
# rm -f *~ */core */*~ */*.o */npbparams.h */*.obj */*.exe
# rm -f sys/setparams sys/makesuite sys/setparams.h
# rm -f {DC/,}ADC.{logf,view,dat,viewsz,groupby,chunks}.*
# rm -f bin/sp.* bin/lu.* bin/mg.* bin/ft.* bin/bt.* bin/is.*
# rm -f bin/ep.* bin/cg.* bin/ua.* bin/dc.*
#    ===========================================
#    =      NAS PARALLEL BENCHMARKS 3.3        =
#    =      Serial Versions                    =
#    =      C                                  =
#    ===========================================
#
# cd FT; make CLASS=A
# make[1]: Entering directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/FT-seq/NPB3.3-SER-C/FT'
# make[2]: Entering directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/FT-seq/NPB3.3-SER-C/sys'
# gcc  -o setparams setparams.c
# make[2]: Leaving directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/FT-seq/NPB3.3-SER-C/sys'
# ../sys/setparams ft A
# gcc  -c -I../common -g -Wall -O3 -mcmodel=medium appft.c
# gcc  -c -I../common -g -Wall -O3 -mcmodel=medium auxfnct.c
# auxfnct.c: In function ‘CompExp’:
# auxfnct.c:46:10: warning: variable ‘nu’ set but not used [-Wunused-but-set-variable]
#    int m, nu, ku, i, j, ln;
#           ^
# auxfnct.c: In function ‘ipow46’:
# auxfnct.c:87:18: warning: variable ‘dummy’ set but not used [-Wunused-but-set-variable]
#    double result, dummy, q, r;
#                   ^
# auxfnct.c: In function ‘compute_initial_conditions’:
# auxfnct.c:140:25: warning: variable ‘dummy’ set but not used [-Wunused-but-set-variable]
#    double x0, start, an, dummy;
#                          ^
# gcc  -c -I../common -g -Wall -O3 -mcmodel=medium fft3d.c
# gcc  -c -I../common -g -Wall -O3 -mcmodel=medium mainft.c
# gcc  -c -I../common -g -Wall -O3 -mcmodel=medium verify.c
# cd ../common; gcc  -c -I../common -g -Wall -O3 -mcmodel=medium randdp.c
# cd ../common; gcc  -c -I../common -g -Wall -O3 -mcmodel=medium print_results.c
# cd ../common; gcc  -c -I../common -g -Wall -O3 -mcmodel=medium c_timers.c
# cd ../common; gcc  -c -I../common -g -Wall -O3 -mcmodel=medium  -o wtime.o ../common/wtime.c
# gcc -O3 -mcmodel=medium -o ../bin/ft.A.x appft.o auxfnct.o fft3d.o mainft.o verify.o ../common/randdp.o ../common/print_results.o ../common/c_timers.o ../common/wtime.o -lm
# make[1]: Leaving directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/FT-seq/NPB3.3-SER-C/FT'

# %%
# !pgprof --cpu-profiling on --cpu-profiling-mode top-down ./NPB-acc/FT-seq/NPB3.3-SER-C/bin/ft.A.x
# Out:
#  NAS Parallel Benchmarks (NPB3.3-SER-C) - FT Benchmark
#
#  Size                :  256x 256x 128
#  Iterations          :              6
#
#  T =    1     Checksum =    5.046735008193E+02    5.114047905510E+02
#  T =    2     Checksum =    5.059412319734E+02    5.098809666433E+02
#  T =    3     Checksum =    5.069376896287E+02    5.098144042213E+02
#  T =    4     Checksum =    5.077892868474E+02    5.101336130759E+02
#  T =    5     Checksum =    5.085233095391E+02    5.104914655194E+02
#  T =    6     Checksum =    5.091487099959E+02    5.107917842803E+02
#  Verification test for FT successful
#
#
#  FT Benchmark Completed.
#  Class           =                        A
#  Size            =            256x 256x 128
#  Iterations      =                        6
#  Time in seconds =                     3.56
#  Mop/s total     =                  2005.08
#  Operation type  =           floating point
#  Verification    =               SUCCESSFUL
#  Version         =                    3.3.1
#  Compile date    =              23 May 2017
#
#  Compile options:
#     CC           = gcc
#     CLINK        = $(CC)
#     C_LIB        = -lm
#     C_INC        = -I../common
#     CFLAGS       = -g -Wall -O3 -mcmodel=medium
#     CLINKFLAGS   = -O3 -mcmodel=medium
#     RAND         = randdp
#
# --------------------------------------
#  Please send all errors/feedbacks to:
#  Center for Manycore Programming
#  cmp@aces.snu.ac.kr
#  http://aces.snu.ac.kr
# --------------------------------------
#
#
# ======== CPU profiling result (top down):
# Time(%)      Time  Name
#  100.00%  4.33999s  main
#  100.00%  4.33999s    appft
#  60.14%     2.61s      fftXYZ
#  50.69%      2.2s      | Swarztrauber
#  18.89%     820ms      compute_initial_conditions
#  18.66%     810ms      | vranlc
#   0.23%      10ms      | ???
#  12.90%     560ms      exp
#   8.99%     390ms      | ???
#   6.91%     300ms      evolve
#
# ======== Data collected at 100Hz frequency

# %% [markdown]
# ### Quality Checking/Keeping a Record
#
# *After each step*, we will record the results from our benchmarking and correctness tests in a table like this one:
#
# |Step| Execution       | ExecutionTime (s)     | Speedup vs. 1 CPU Thread       | Correct? | Programming Time |
# |:--:| --------------- | ---------------------:| ------------------------------:|:--------:| -----------------|
# |1   | CPU 1 thread    | 3.56           |                                | Yes      |                |  |

# %% [markdown]
# Swarztrauber takes most of the time to compute

# %% [markdown]
# ## Step 2 - Add Compute Directives

# %% [markdown]
# Things need to to before you add #pragma ...
#     1. Initiate the GPU
#         acc_init(acc_device_default);
#     2. Create the variables on GPU needed to run
#         #pragma acc data create(u0_real,u0_imag,u1_real,u1_imag,u_real,u_imag, twiddle,gty1_real,gty1_imag, gty2_real, gty2_imag)
#         {
#             ...
#          }
#     3. compute_initial_conditions(), this function calculate the initiate conditon in cpu. In order to use GPU, we need to update the variable in GPU too.
#
#         Add #pragma acc update device(var) at the end of the function to update relative variable in GPU

# %% [markdown]
# #### Then locate for loops
# ##### Add '#pragma acc parallel loop' at the front
# ##### Compiler will tell if the loop is paralleiziable

# %%
# !cd ./NPB-acc/FT-step1/ && make clean && make CC=pgcc CLASS=A
# Out:
# rm -f *.x *.i *.B *.spin *.s *.t *.w2c.c *.w2c.h *.w2c.cu *.ptx *.o *~ mputil* ../common/*.o
# rm -f ft npbparams.h core
# if [ -d rii_files ]; then rm -r rii_files; fi
# make[1]: Entering directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# rm -f setparams setparams.h npbparams.h
# rm -f *~ *.o
# cc  -o setparams setparams.c
# make[1]: Leaving directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# ../sys/setparams ft A
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 ft.c
# main:
#     217, Generating create(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
# init_ui:
#     280, Generating present(twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         281, #pragma acc loop gang /* blockIdx.x */
#         282, #pragma acc loop seq
#         283, #pragma acc loop vector(128) /* threadIdx.x */
#     282, Loop carried dependence of twiddle,u0_imag,u0_real,u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of twiddle,u0_imag,u0_real,u1_imag,u1_real prevents vectorization
#     283, Loop is parallelizable
# evolve:
#     303, Generating present(twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         304, #pragma acc loop gang /* blockIdx.x */
#         305, #pragma acc loop seq
#         306, #pragma acc loop vector(128) /* threadIdx.x */
#     305, Loop carried dependence of u0_imag,u0_real,u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u0_imag,u0_real,u1_imag,u1_real prevents vectorization
#          Loop carried dependence of u0_imag,u0_real prevents vectorization
#     306, Loop is parallelizable
# compute_initial_conditions:
#     389, Generating update device(u1_imag[:],u1_real[:])
# compute_indexmap:
#     487, Generating implicit copyout(twiddle[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         488, #pragma acc loop gang /* blockIdx.x */
#         489, #pragma acc loop seq
#         490, #pragma acc loop vector(128) /* threadIdx.x */
#     489, Loop carried dependence of twiddle prevents parallelization
#          Loop carried backward dependence of twiddle prevents vectorization
#     490, Loop is parallelizable
# fft_init:
#     543, Generating implicit copyout(u_imag[0],u_real[0])
#          Accelerator kernel generated
#          Generating Tesla code
#     554, Generating present(u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         557, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
# cffts1_pos:
#     604, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         607, #pragma acc loop gang /* blockIdx.x */
#         608, #pragma acc loop seq
#         609, #pragma acc loop vector(128) /* threadIdx.x */
#         614, #pragma acc loop seq
#         620, #pragma acc loop seq
#         621, #pragma acc loop seq
#         647, #pragma acc loop vector(128) /* threadIdx.x */
#         658, #pragma acc loop seq
#         659, #pragma acc loop seq
#         686, #pragma acc loop vector(128) /* threadIdx.x */
#     608, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Complex loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
#     609, Loop is parallelizable
#     614, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     620, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     621, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     647, Loop is parallelizable
#     658, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     659, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#     686, Loop is parallelizable
# cffts1_neg:
#     710, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         714, #pragma acc loop gang /* blockIdx.x */
#         715, #pragma acc loop seq
#         716, #pragma acc loop vector(128) /* threadIdx.x */
#         721, #pragma acc loop seq
#         727, #pragma acc loop seq
#         728, #pragma acc loop seq
#         754, #pragma acc loop vector(128) /* threadIdx.x */
#         765, #pragma acc loop seq
#         766, #pragma acc loop seq
#         793, #pragma acc loop vector(128) /* threadIdx.x */
#     715, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Complex loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
#     716, Loop is parallelizable
#     721, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     727, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     728, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     754, Loop is parallelizable
#     765, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     766, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#     793, Loop is parallelizable
# cffts2_pos:
#     818, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         822, #pragma acc loop gang /* blockIdx.x */
#         823, #pragma acc loop seq
#         824, #pragma acc loop vector(128) /* threadIdx.x */
#         829, #pragma acc loop seq
#         835, #pragma acc loop seq
#         836, #pragma acc loop seq
#         862, #pragma acc loop vector(128) /* threadIdx.x */
#         874, #pragma acc loop seq
#         875, #pragma acc loop seq
#         902, #pragma acc loop seq
#     823, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Complex loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
#     824, Loop is parallelizable
#     829, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     835, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     836, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     862, Loop is parallelizable
#     874, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     875, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#     902, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
# cffts2_neg:
#     926, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         930, #pragma acc loop gang /* blockIdx.x */
#         931, #pragma acc loop seq
#         932, #pragma acc loop vector(128) /* threadIdx.x */
#         937, #pragma acc loop seq
#         943, #pragma acc loop seq
#         944, #pragma acc loop seq
#         970, #pragma acc loop vector(128) /* threadIdx.x */
#         981, #pragma acc loop seq
#         982, #pragma acc loop seq
#        1009, #pragma acc loop seq
#     931, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Complex loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
#     932, Loop is parallelizable
#     937, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     943, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     944, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     970, Loop is parallelizable
#     981, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     982, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#    1009, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
# cffts3_pos:
#    1034, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#        1038, #pragma acc loop gang /* blockIdx.x */
#        1039, #pragma acc loop seq
#        1040, #pragma acc loop vector(128) /* threadIdx.x */
#        1045, #pragma acc loop seq
#        1051, #pragma acc loop seq
#        1052, #pragma acc loop seq
#        1078, #pragma acc loop vector(128) /* threadIdx.x */
#        1089, #pragma acc loop seq
#        1090, #pragma acc loop seq
#        1117, #pragma acc loop seq
#    1039, Loop carried dependence of u0_imag,u0_real prevents parallelization
#          Loop carried backward dependence of u0_imag,u0_real prevents vectorization
#    1040, Loop is parallelizable
#    1045, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1051, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1052, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1078, Loop is parallelizable
#    1089, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1090, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#    1117, Loop carried dependence of u0_imag,u0_real prevents parallelization
#          Loop carried backward dependence of u0_imag,u0_real prevents vectorization
# cffts3_neg:
#    1144, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#        1148, #pragma acc loop gang /* blockIdx.x */
#        1149, #pragma acc loop seq
#        1150, #pragma acc loop vector(128) /* threadIdx.x */
#        1155, #pragma acc loop seq
#        1161, #pragma acc loop seq
#        1162, #pragma acc loop seq
#        1188, #pragma acc loop vector(128) /* threadIdx.x */
#        1199, #pragma acc loop seq
#        1200, #pragma acc loop seq
#        1227, #pragma acc loop seq
#    1149, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Complex loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
#    1150, Loop is parallelizable
#    1155, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1161, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1162, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1188, Loop is parallelizable
#    1199, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1200, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#    1227, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
# checksum:
#    1265, Generating present(u1_imag[:],u1_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#        1268, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#              Generating reduction(+:temp1,temp2)
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 randdp.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 print_results.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 c_timers.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 wtime.c
# pgcc -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -o ./ft.A.x ft.o randdp.o print_results.o c_timers.o wtime.o -lm

# %% [markdown]
# If you get any error please check your work and try re-compilling.

# %%
# !ulimit -s unlimited && ./NPB-acc/FT-step1/ft.A.x
# Out:
#  NAS Parallel Benchmarks (NPB3.3-ACC-C) - FT Benchmark
#
#  Size                :  256x 256x 128
#  Iterations                  :      6
#
#  T =    1     Checksum =    5.046735008193E+02    5.114047905510E+02
#  T =    2     Checksum =    5.059412319734E+02    5.098809666433E+02
#  T =    3     Checksum =    5.069376896287E+02    5.098144042213E+02
#  T =    4     Checksum =    5.077892868474E+02    5.101336130759E+02
#  T =    5     Checksum =    5.085233095391E+02    5.104914655194E+02
#  T =    6     Checksum =    5.091487099959E+02    5.107917842803E+02
#  Result verification successful
#  class = A
#
#
#  FT Benchmark Completed.
#  Class           =                        A
#  Size            =            256x 256x 128
#  Iterations      =                        6
#  Time in seconds =                     8.94
#  Mop/s total     =                   798.12
#  Operation type  =           floating point
#  Verification    =               SUCCESSFUL
#  Version         =                    3.3.1
#  Compile date    =              23 May 2017
#
#  Compile options:
#     CC           = (none)
#     CLINK        = (none)
#     C_LIB        = -lm
#     C_INC        = -I../common
#     CFLAGS       = (none)
#     CLINKFLAGS   = (none)
#     RAND         = randdp
#
# --------------------------------------
#  Please send all errors/feedbacks to:
#  Center for Manycore Programming
#  cmp@aces.snu.ac.kr
#  http://aces.snu.ac.kr
# --------------------------------------

# %% [markdown]
# Let's record our results in the table:
#
# |Step| Execution    | Time(s)     | Speedup vs. 1 CPU Thread  | Correct? | Programming Time |
# | -- || ------------ | ----------- | ------------------------- | -------- | ---------------- |
# |1| CPU 1 thread |3.56      |                           |          | |
# |2| Add parallel directive  |8.94      | 0.40X           | Yes      | ||

# %% [markdown]
# ### Some loops running sequentially
#
# Solution: add independent clauses

# %%
# !cd ./NPB-acc/FT-step1/ && make clean && make CC=pgcc CLASS=A
# Out:
# rm -f *.x *.i *.B *.spin *.s *.t *.w2c.c *.w2c.h *.w2c.cu *.ptx *.o *~ mputil* ../common/*.o
# rm -f ft npbparams.h core
# if [ -d rii_files ]; then rm -r rii_files; fi
# make[1]: Entering directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# rm -f setparams setparams.h npbparams.h
# rm -f *~ *.o
# cc  -o setparams setparams.c
# make[1]: Leaving directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# ../sys/setparams ft A
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 ft.c
# main:
#     217, Generating create(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
# init_ui:
#     280, Generating present(twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         283, #pragma acc loop gang /* blockIdx.x */
#         285, #pragma acc loop worker(4) /* threadIdx.y */
#         287, #pragma acc loop vector(32) /* threadIdx.x */
#     285, Loop is parallelizable
#     287, Loop is parallelizable
# evolve:
#     307, Generating present(twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         310, #pragma acc loop gang /* blockIdx.x */
#         312, #pragma acc loop worker(4) /* threadIdx.y */
#         314, #pragma acc loop vector(32) /* threadIdx.x */
#     312, Loop is parallelizable
#     314, Loop is parallelizable
# compute_initial_conditions:
#     398, Generating update device(u1_imag[:],u1_real[:])
# compute_indexmap:
#     496, Generating implicit copyout(twiddle[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         499, #pragma acc loop gang /* blockIdx.x */
#         501, #pragma acc loop worker(4) /* threadIdx.y */
#         503, #pragma acc loop vector(32) /* threadIdx.x */
#     501, Loop is parallelizable
#     503, Loop is parallelizable
# fft_init:
#     557, Generating present(u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#     568, Generating present(u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         571, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
# cffts1_pos:
#     618, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         621, #pragma acc loop gang /* blockIdx.x */
#         623, #pragma acc loop vector(128) /* threadIdx.x */
#         624, #pragma acc loop seq
#         629, #pragma acc loop seq
#         635, #pragma acc loop seq
#         636, #pragma acc loop seq
#         662, #pragma acc loop seq
#         673, #pragma acc loop seq
#         674, #pragma acc loop seq
#         701, #pragma acc loop seq
#     623, Loop is parallelizable
#     624, Loop is parallelizable
#     629, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     635, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     636, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     662, Loop is parallelizable
#     673, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     674, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#     701, Loop is parallelizable
# cffts1_neg:
#     725, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         729, #pragma acc loop gang /* blockIdx.x */
#         731, #pragma acc loop vector(128) /* threadIdx.x */
#         732, #pragma acc loop seq
#         737, #pragma acc loop seq
#         743, #pragma acc loop seq
#         744, #pragma acc loop seq
#         770, #pragma acc loop seq
#         781, #pragma acc loop seq
#         782, #pragma acc loop seq
#         809, #pragma acc loop seq
#     731, Loop is parallelizable
#     732, Loop is parallelizable
#     737, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     743, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     744, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     770, Loop is parallelizable
#     781, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     782, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#     809, Loop is parallelizable
# cffts2_pos:
#     834, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         838, #pragma acc loop gang /* blockIdx.x */
#         840, #pragma acc loop vector(128) /* threadIdx.x */
#         841, #pragma acc loop seq
#         846, #pragma acc loop seq
#         852, #pragma acc loop seq
#         853, #pragma acc loop seq
#         879, #pragma acc loop seq
#         891, #pragma acc loop seq
#         892, #pragma acc loop seq
#         919, #pragma acc loop seq
#     840, Loop is parallelizable
#     841, Loop is parallelizable
#     846, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     852, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     853, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     879, Loop is parallelizable
#     891, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     892, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#     919, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
# cffts2_neg:
#     943, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#         947, #pragma acc loop gang /* blockIdx.x */
#         949, #pragma acc loop vector(128) /* threadIdx.x */
#         950, #pragma acc loop seq
#         955, #pragma acc loop seq
#         961, #pragma acc loop seq
#         962, #pragma acc loop seq
#         988, #pragma acc loop seq
#         999, #pragma acc loop seq
#        1000, #pragma acc loop seq
#        1027, #pragma acc loop seq
#     949, Loop is parallelizable
#     950, Loop is parallelizable
#     955, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     961, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     962, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     988, Loop is parallelizable
#     999, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1000, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#    1027, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
# cffts3_pos:
#    1052, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#        1056, #pragma acc loop gang /* blockIdx.x */
#        1058, #pragma acc loop vector(128) /* threadIdx.x */
#        1059, #pragma acc loop seq
#        1064, #pragma acc loop seq
#        1070, #pragma acc loop seq
#        1071, #pragma acc loop seq
#        1097, #pragma acc loop seq
#        1108, #pragma acc loop seq
#        1109, #pragma acc loop seq
#        1136, #pragma acc loop seq
#    1058, Loop is parallelizable
#    1059, Loop is parallelizable
#    1064, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1070, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1071, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1097, Loop is parallelizable
#    1108, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1109, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#    1136, Loop carried dependence of u0_imag,u0_real prevents parallelization
#          Loop carried backward dependence of u0_imag,u0_real prevents vectorization
# cffts3_neg:
#    1163, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#        1167, #pragma acc loop gang /* blockIdx.x */
#        1169, #pragma acc loop vector(128) /* threadIdx.x */
#        1170, #pragma acc loop seq
#        1175, #pragma acc loop seq
#        1181, #pragma acc loop seq
#        1182, #pragma acc loop seq
#        1208, #pragma acc loop seq
#        1219, #pragma acc loop seq
#        1220, #pragma acc loop seq
#        1247, #pragma acc loop seq
#    1169, Loop is parallelizable
#    1170, Loop is parallelizable
#    1175, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1181, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1182, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1208, Loop is parallelizable
#    1219, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1220, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#    1247, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
# checksum:
#    1285, Generating present(u1_imag[:],u1_real[:])
#          Accelerator kernel generated
#          Generating Tesla code
#        1288, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#              Generating reduction(+:temp1,temp2)
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 randdp.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 print_results.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 c_timers.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 wtime.c
# pgcc -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -o ./ft.A.x ft.o randdp.o print_results.o c_timers.o wtime.o -lm

# %%
# !ulimit -s unlimited && ./NPB-acc/FT-step1/ft.A.x
# Out:
#  NAS Parallel Benchmarks (NPB3.3-ACC-C) - FT Benchmark
#
#  Size                :  256x 256x 128
#  Iterations                  :      6
#
#  T =    1     Checksum =    5.046735008193E+02    5.114047905510E+02
#  T =    2     Checksum =    5.059412319734E+02    5.098809666433E+02
#  T =    3     Checksum =    5.069376896287E+02    5.098144042213E+02
#  T =    4     Checksum =    5.077892868474E+02    5.101336130759E+02
#  T =    5     Checksum =    5.085233095391E+02    5.104914655194E+02
#  T =    6     Checksum =    5.091487099959E+02    5.107917842803E+02
#  Result verification successful
#  class = A
#
#
#  FT Benchmark Completed.
#  Class           =                        A
#  Size            =            256x 256x 128
#  Iterations      =                        6
#  Time in seconds =                     0.78
#  Mop/s total     =                  9198.01
#  Operation type  =           floating point
#  Verification    =               SUCCESSFUL
#  Version         =                    3.3.1
#  Compile date    =              23 May 2017
#
#  Compile options:
#     CC           = (none)
#     CLINK        = (none)
#     C_LIB        = -lm
#     C_INC        = -I../common
#     CFLAGS       = (none)
#     CLINKFLAGS   = (none)
#     RAND         = randdp
#
# --------------------------------------
#  Please send all errors/feedbacks to:
#  Center for Manycore Programming
#  cmp@aces.snu.ac.kr
#  http://aces.snu.ac.kr
# --------------------------------------

# %% [markdown]
# Let's record our results in the table:
#
# |Step| Execution    | Time(s)     | Speedup vs. 1 CPU Thread  | Correct? | Programming Time |
# | -- || ------------ | ----------- | ------------------------- | -------- | ---------------- |
# |1| CPU 1 thread |3.56      |                           |          | |
# |2| Add parallel directive  |8.94      | 0.40X           | Yes      | |
# |3| Add independent clause  |0.78      | 4.56X           | Yes      | ||

# %% [markdown]
# ### optimization
# Manully control the block dimension
#
# Like:
#     #pragma acc parallel num_gangs(d3) num_workers(8) vector_length(128)

# %%
# !cd ./NPB-acc/FT-final/ && make clean && make CC=pgcc CLASS=A
# Out:
# rm -f *.x *.i *.B *.spin *.s *.t *.w2c.c *.w2c.h *.w2c.cu *.ptx *.o *~ mputil* ../common/*.o
# rm -f ft npbparams.h core
# if [ -d rii_files ]; then rm -r rii_files; fi
# make[1]: Entering directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# rm -f setparams setparams.h npbparams.h
# rm -f *~ *.o
# cc  -o setparams setparams.c
# make[1]: Leaving directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# ../sys/setparams ft A
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 ft.c
# main:
#     217, Generating create(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
# init_ui:
#     284, Generating present(twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:])
#     288, Loop is parallelizable
#     290, Loop is parallelizable
#     292, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         288, #pragma acc loop gang /* blockIdx.y */
#         290, #pragma acc loop gang, worker(4) /* blockIdx.x threadIdx.y */
#         292, #pragma acc loop gang, vector(32) /* blockIdx.z threadIdx.x */
# evolve:
#     316, Generating present(twiddle[:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:])
#     320, Loop is parallelizable
#     322, Loop is parallelizable
#     324, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         320, #pragma acc loop gang /* blockIdx.y */
#         322, #pragma acc loop gang, worker(4) /* blockIdx.x threadIdx.y */
#         324, #pragma acc loop gang, vector(32) /* blockIdx.z threadIdx.x */
# compute_initial_conditions:
#     408, Generating update device(u1_imag[:],u1_real[:])
# compute_indexmap:
#     509, Generating present(twiddle[:])
#     513, Loop is parallelizable
#     515, Loop is parallelizable
#     517, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         513, #pragma acc loop gang /* blockIdx.y */
#         515, #pragma acc loop gang, worker(4) /* blockIdx.x threadIdx.y */
#         517, #pragma acc loop gang, vector(32) /* blockIdx.z threadIdx.x */
# fft_init:
#     574, Generating present(u_imag[:],u_real[:])
#          Accelerator kernel generated
#          Accelerator scalar kernel generated
#     589, Generating present(u_imag[:],u_real[:])
#     593, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         593, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
# cffts1_pos:
#     645, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#     650, Loop is parallelizable
#     652, Loop is parallelizable
#     653, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         650, #pragma acc loop gang /* blockIdx.x */
#         652, #pragma acc loop gang, vector(4) /* blockIdx.z threadIdx.y */
#         653, #pragma acc loop gang, vector(32) /* blockIdx.y threadIdx.x */
#     658, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#          Accelerator kernel generated
#          Generating Tesla code
#         650, #pragma acc loop gang /* blockIdx.x */
#         652, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#         658, #pragma acc loop seq
#         664, #pragma acc loop seq
#         665, #pragma acc loop seq
#         691, #pragma acc loop seq
#         702, #pragma acc loop seq
#         703, #pragma acc loop seq
#     664, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     665, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#     691, Loop is parallelizable
#     702, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     703, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#     730, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         650, #pragma acc loop gang /* blockIdx.x */
#         652, #pragma acc loop gang, vector(4) /* blockIdx.z threadIdx.y */
#         730, #pragma acc loop gang, vector(32) /* blockIdx.y threadIdx.x */
# cffts1_neg:
#     759, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#     764, Loop is parallelizable
#     766, Loop is parallelizable
#     767, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         764, #pragma acc loop gang /* blockIdx.x */
#         766, #pragma acc loop gang, vector(4) /* blockIdx.z threadIdx.y */
#         767, #pragma acc loop gang, vector(32) /* blockIdx.y threadIdx.x */
#     772, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#          Accelerator kernel generated
#          Generating Tesla code
#         764, #pragma acc loop gang /* blockIdx.x */
#         766, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#         772, #pragma acc loop seq
#         778, #pragma acc loop seq
#         779, #pragma acc loop seq
#         805, #pragma acc loop seq
#         816, #pragma acc loop seq
#         817, #pragma acc loop seq
#     778, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     779, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#     805, Loop is parallelizable
#     816, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     817, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#     844, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         764, #pragma acc loop gang /* blockIdx.x */
#         766, #pragma acc loop gang, vector(4) /* blockIdx.z threadIdx.y */
#         844, #pragma acc loop gang, vector(32) /* blockIdx.y threadIdx.x */
# cffts2_pos:
#     874, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#     879, Loop is parallelizable
#     881, Loop is parallelizable
#     882, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         879, #pragma acc loop gang /* blockIdx.x */
#         881, #pragma acc loop gang, vector(128) /* blockIdx.z threadIdx.x */
#         882, #pragma acc loop gang /* blockIdx.y */
#     887, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#          Accelerator kernel generated
#          Generating Tesla code
#         879, #pragma acc loop gang /* blockIdx.x */
#         881, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#         887, #pragma acc loop seq
#         893, #pragma acc loop seq
#         894, #pragma acc loop seq
#         920, #pragma acc loop seq
#         932, #pragma acc loop seq
#         933, #pragma acc loop seq
#     893, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#     894, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#     920, Loop is parallelizable
#     932, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#     933, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#     960, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
#          Inner sequential loop scheduled on accelerator
#          Accelerator kernel generated
#          Generating Tesla code
#         879, #pragma acc loop gang /* blockIdx.x */
#         881, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#         960, #pragma acc loop seq
# cffts2_neg:
#     989, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#     994, Loop is parallelizable
#     996, Loop is parallelizable
#     997, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         994, #pragma acc loop gang /* blockIdx.x */
#         996, #pragma acc loop gang, vector(128) /* blockIdx.z threadIdx.x */
#         997, #pragma acc loop gang /* blockIdx.y */
#    1002, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#          Accelerator kernel generated
#          Generating Tesla code
#         994, #pragma acc loop gang /* blockIdx.x */
#         996, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#        1002, #pragma acc loop seq
#        1008, #pragma acc loop seq
#        1009, #pragma acc loop seq
#        1035, #pragma acc loop seq
#        1046, #pragma acc loop seq
#        1047, #pragma acc loop seq
#    1008, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1009, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#    1035, Loop is parallelizable
#    1046, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1047, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#    1074, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
#          Inner sequential loop scheduled on accelerator
#          Accelerator kernel generated
#          Generating Tesla code
#         994, #pragma acc loop gang /* blockIdx.x */
#         996, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#        1074, #pragma acc loop seq
# cffts3_pos:
#    1104, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u0_imag[:],u0_real[:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#    1109, Loop is parallelizable
#    1111, Loop is parallelizable
#    1112, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#        1109, #pragma acc loop gang /* blockIdx.x */
#        1111, #pragma acc loop gang, vector(128) /* blockIdx.z threadIdx.x */
#        1112, #pragma acc loop gang /* blockIdx.y */
#    1117, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#          Accelerator kernel generated
#          Generating Tesla code
#        1109, #pragma acc loop gang /* blockIdx.x */
#        1111, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#        1117, #pragma acc loop seq
#        1123, #pragma acc loop seq
#        1124, #pragma acc loop seq
#        1150, #pragma acc loop seq
#        1161, #pragma acc loop seq
#        1162, #pragma acc loop seq
#    1123, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1124, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#    1150, Loop is parallelizable
#    1161, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1162, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#    1189, Loop carried dependence of u0_imag,u0_real prevents parallelization
#          Loop carried backward dependence of u0_imag,u0_real prevents vectorization
#          Inner sequential loop scheduled on accelerator
#          Accelerator kernel generated
#          Generating Tesla code
#        1109, #pragma acc loop gang /* blockIdx.x */
#        1111, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#        1189, #pragma acc loop seq
# cffts3_neg:
#    1221, Generating present(gty1_imag[:][:][:],gty1_real[:][:][:],gty2_imag[:][:][:],gty2_real[:][:][:],u1_imag[:],u1_real[:],u_imag[:],u_real[:])
#    1226, Loop is parallelizable
#    1228, Loop is parallelizable
#    1229, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#        1226, #pragma acc loop gang /* blockIdx.x */
#        1228, #pragma acc loop gang, vector(128) /* blockIdx.z threadIdx.x */
#        1229, #pragma acc loop gang /* blockIdx.y */
#    1234, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Complex loop carried dependence of gty1_imag,gty1_real,gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#          Accelerator kernel generated
#          Generating Tesla code
#        1226, #pragma acc loop gang /* blockIdx.x */
#        1228, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#        1234, #pragma acc loop seq
#        1240, #pragma acc loop seq
#        1241, #pragma acc loop seq
#        1267, #pragma acc loop seq
#        1278, #pragma acc loop seq
#        1279, #pragma acc loop seq
#    1240, Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#    1241, Complex loop carried dependence of gty2_imag,gty2_real prevents parallelization
#          Loop carried reuse of gty2_imag,gty2_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#    1267, Loop is parallelizable
#    1278, Loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried backward dependence of gty1_imag,gty1_real prevents vectorization
#          Loop carried dependence of gty1_imag,gty1_real prevents vectorization
#    1279, Complex loop carried dependence of gty1_imag,gty1_real prevents parallelization
#          Loop carried reuse of gty1_imag,gty1_real prevents parallelization
#          Inner sequential loop scheduled on accelerator
#    1306, Loop carried dependence of u1_imag,u1_real prevents parallelization
#          Loop carried backward dependence of u1_imag,u1_real prevents vectorization
#          Inner sequential loop scheduled on accelerator
#          Accelerator kernel generated
#          Generating Tesla code
#        1226, #pragma acc loop gang /* blockIdx.x */
#        1228, #pragma acc loop gang, vector(128) /* blockIdx.y threadIdx.x */
#        1306, #pragma acc loop seq
# checksum:
#    1348, Generating present(u1_imag[:],u1_real[:])
#    1352, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#        1352, #pragma acc loop gang, worker(4), vector(32) /* blockIdx.x threadIdx.y threadIdx.x */
#              Generating reduction(+:temp1,temp2)
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 randdp.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 print_results.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 c_timers.c
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 wtime.c
# pgcc -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -o ./ft.A.x ft.o randdp.o print_results.o c_timers.o wtime.o -lm

# %%
# !./NPB-acc/FT-final/ft.A.x
# Out:
#  NAS Parallel Benchmarks (NPB3.3-ACC-C) - FT Benchmark
#
#  Size                :  256x 256x 128
#  Iterations                  :      6
#
#  T =    1     Checksum =    5.046735008193E+02    5.114047905510E+02
#  T =    2     Checksum =    5.059412319734E+02    5.098809666433E+02
#  T =    3     Checksum =    5.069376896287E+02    5.098144042213E+02
#  T =    4     Checksum =    5.077892868474E+02    5.101336130759E+02
#  T =    5     Checksum =    5.085233095391E+02    5.104914655194E+02
#  T =    6     Checksum =    5.091487099959E+02    5.107917842803E+02
#  Result verification successful
#  class = A
#
#
#  FT Benchmark Completed.
#  Class           =                        A
#  Size            =            256x 256x 128
#  Iterations      =                        6
#  Time in seconds =                     0.67
#  Mop/s total     =                 10696.01
#  Operation type  =           floating point
#  Verification    =               SUCCESSFUL
#  Version         =                    3.3.1
#  Compile date    =              23 May 2017
#
#  Compile options:
#     CC           = (none)
#     CLINK        = (none)
#     C_LIB        = -lm
#     C_INC        = -I../common
#     CFLAGS       = (none)
#     CLINKFLAGS   = (none)
#     RAND         = randdp
#
# --------------------------------------
#  Please send all errors/feedbacks to:
#  Center for Manycore Programming
#  cmp@aces.snu.ac.kr
#  http://aces.snu.ac.kr
# --------------------------------------

# %% [markdown]
# Let's record our results in the table:
#
# |Step| Execution    | Time(s)     | Speedup vs. 1 CPU Thread  | Correct? | Programming Time |
# | -- || ------------ | ----------- | ------------------------- | -------- | ---------------- |
# |1| CPU 1 thread |3.56      |                           |          | |
# |2| Add parallel directive  |8.94      | 0.40X           | Yes      | |
# |3| Add independent clause  |0.78      | 4.56X           | Yes      | |
# |4| Optimization  |0.67      | 5.31X           | Yes      | ||
