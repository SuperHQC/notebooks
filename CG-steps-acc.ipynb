# %% [markdown]
# ## NPB-openACC-C-CG Implementation
# In this self-paced, hands-on lab, we will briefly explore some methods for OpenACC
#
# Qichao Hong

# %% [markdown]
# ---
# Before we begin, let's verify [WebSockets](http://en.wikipedia.org/wiki/WebSocket) are working on your system.  To do this, execute the cell block below by giving it focus (clicking on it with your mouse), and hitting Ctrl-Enter, or pressing the play button in the toolbar above.  If all goes well, you should see get some output returned below the grey cell.  If not, please consult the [Self-paced Lab Troubleshooting FAQ](https://developer.nvidia.com/self-paced-labs-faq#Troubleshooting) to debug the issue.

# %%
print ("The answer should be three: " + str(1+2))
# Out:
# The answer should be three: 3

# %% [markdown]
# First, run the cell below to get some info about the GPUs on the server.

# %%
# !nvidia-smi
# Out:
# Tue May 23 07:49:32 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.51                 Driver Version: 375.51                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 780 Ti  Off  | 0000:01:00.0     N/A |                  N/A |
# | 31%   42C    P8    N/A /  N/A |    345MiB /  3017MiB |     N/A      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 780 Ti  Off  | 0000:02:00.0     N/A |                  N/A |
# | 26%   40C    P8    N/A /  N/A |      1MiB /  3020MiB |     N/A      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |    0                  Not Supported                                         |
# |    1                  Not Supported                                         |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# CPU: Intel i7-4960x

# %% [markdown]
# ---
# <p class="hint_trigger">If you have never before taken an IPython Notebook based self-paced lab from NVIDIA, click this green box.
#       <div class="toggle_container"><div class="input_area box-flex1"><div class=\"highlight\">The following video will explain the infrastructure we are using for this self-paced lab, as well as give some tips on it's usage.  If you've never taken a lab on this system before, it's highly encourage you watch this short video first.<br><br>
# <div align="center"><iframe width="640" height="390" src="http://www.youtube.com/embed/ZMrDaLSFqpY" frameborder="0" allowfullscreen></iframe></div>
# <br>
# <h2 style="text-align:center;color:red;">Attention Firefox Users</h2><div style="text-align:center; margin: 0px 25px 0px 25px;">There is a bug with Firefox related to setting focus in any text editors embedded in this lab. Even though the cursor may be blinking in the text editor, focus for the keyboard may not be there, and any keys you press may be applying to the previously selected cell.  To work around this issue, you'll need to first click in the margin of the browser window (where there are no cells) and then in the text editor.  Sorry for this inconvenience, we're working on getting this fixed.</div></div></div></div></p>

# %% [markdown]
# ## Introduction to OpenACC
#
# Open-specification OpenACC directives are a straightforward way to accelerate existing Fortran and C applications. With OpenACC directives, you provide hints via compiler directives (or 'pragmas') to tell the compiler where -- and how -- it should parallelize compute-intensive code for execution on an accelerator.
#
# If you've done parallel programming using OpenMP, OpenACC is very similar: using directives, applications can be parallelized *incrementally*, with little or no change to the Fortran, C or C++ source. Debugging and code maintenance are easier. OpenACC directives are designed for *portability* across operating systems, host CPUs, and accelerators. You can use OpenACC directives with GPU accelerated libraries, explicit parallel programming languages (e.g., CUDA), MPI, and OpenMP, *all in the same program.*
#
# Watch the following short video introduction to OpenACC:
#
# <div align="center"><iframe width="640" height="390" style="margin: 0 auto;" src="http://www.youtube.com/embed/c9WYCFEt_Uo" frameborder="0" allowfullscreen></iframe></div>
#
# This hands-on lab walks you through a short sample of a scientific code, and demonstrates how you can employ OpenACC directives using a four-step process. You will make modifications to a simple C program, then compile and execute the newly enhanced code in each step. Along the way, hints and solution are provided, so you can check your work, or take a peek if you get lost.
#
# If you are confused now, or at any point in this lab, you can consult the <a href="#FAQ">FAQ</a> located at the bottom of this page.

# %% [markdown]
# # Step 1 - Characterize Your Application

# %% [markdown]
# The most difficult part of accelerator programming begins before the first line of code is written. If your program is not highly parallel, an accelerator or coprocesor won't be much use. Understanding the code structure is crucial if you are going to *identify opportunities* and *successfully* parallelize a piece of code. The first step in OpenACC programming then is to *characterize the application*. This includes:
#
# + benchmarking the single-thread, CPU-only version of the application
# + understanding the program structure and how data is passed through the call tree
# + profiling the application and identifying computationally-intense "hot spots"
#     + which loop nests dominate the runtime?
#     + what are the minimum/average/maximum tripcounts through these loop nests?
#     + are the loop nests suitable for an accelerator?
# + insuring that the algorithms you are considering for acceleration are *safely* parallel
#
# Note: what we've just said may sound a little scary, so please note that as parallel programming methods go OpenACC is really pretty friendly: think of it as a sandbox you can play in. Because OpenACC directives are incremental, you can add one or two directives at a time and see how things work: the compiler provides a *lot* of feedback. The right software plus good tools plus educational experiences like this one should put you on the path to successfully accelerating your programs.

# %% [markdown]
# ## Step 1 Profiling and Benchmarking
#
# Before you start modifying code and adding OpenACC directives, you should benchmark the serial version of the program. To facilitate benchmarking after this and every other step in our parallel porting effort, we have built a timing routine around the main structure of our program -- a process we recommend you follow in your own efforts. Let's run the `BT` file without making any changes -- and see how fast the serial program executes. This will establish a baseline for future comparisons.  Execute the following two cells to compile and run the program.

# %%
# !cd ./NPB-acc/CG-seq/ && make clean && make CG CLASS=B
# Out:
# rm -f *.x *.w2c.ptx *.o *.w2c.cu *.w2c.c *.w2c.h *.i *.spin *.B *.s *.t *~ ../common/*.o
# rm -f npbparams.h core
# make[1]: Entering directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# rm -f setparams setparams.h npbparams.h
# rm -f *~ *.o
# cc  -o setparams setparams.c
# make[1]: Leaving directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# ../sys/setparams cg B
# cc  -c -I../common  -DCRPL_COMP=0 cg.c
# cd ../common; cc  -c -I../common  print_results.c
# cd ../common; cc  -c -I../common  randdp.c
# cd ../common; cc  -c -I../common  c_timers.c
# cd ../common; cc  -c -I../common   -o wtime.o ../common/wtime.c
# cc  -o ./cg.B.x cg.o ../common/print_results.o ../common/randdp.o ../common/c_timers.o ../common/wtime.o -lm

# %%
# !pgprof --cpu-profiling on --cpu-profiling-mode top-down ./NPB-acc/CG-seq/cg.B.x
# Out:
#  NAS Parallel Benchmarks (NPB3.3-SER-C) - CG Benchmark
#
#  Size:       75000
#  Iterations:    75
#
#  Initialization time =           9.300 seconds
#
#    iteration           ||r||                 zeta
#         1       2.27623230253657E-13    59.9994751578754
#         2       8.44559392893216E-16    21.7627846142536
#         3       8.64511022632338E-16    22.2876617043224
#         4       8.61697722482409E-16    22.5230738188346
#         5       8.71222095709208E-16    22.6275390653892
#         6       8.71977185255567E-16    22.6740259189533
#         7       8.73832261918524E-16    22.6949056826251
#         8       8.87870239801501E-16    22.7044023166872
#         9       8.83216527363961E-16    22.7087834345620
#        10       8.80909464617773E-16    22.7108351397177
#        11       8.80803816383157E-16    22.7118107121341
#        12       8.84631507363274E-16    22.7122816240971
#        13       8.84386307708107E-16    22.7125122663242
#        14       8.85738245256241E-16    22.7126268007594
#        15       8.69465189590021E-16    22.7126844161819
#        16       8.80464475795608E-16    22.7127137461755
#        17       8.79208229388488E-16    22.7127288402000
#        18       8.84495944057552E-16    22.7127366848296
#        19       8.87459020956502E-16    22.7127407981217
#        20       8.78738608788050E-16    22.7127429721364
#        21       8.79063996233035E-16    22.7127441294025
#        22       8.77561970738108E-16    22.7127447493901
#        23       8.73438042797631E-16    22.7127450834533
#        24       8.78562496292348E-16    22.7127452643881
#        25       8.75015123991464E-16    22.7127453628451
#        26       8.81271487788102E-16    22.7127454166517
#        27       8.72205152729482E-16    22.7127454461696
#        28       8.78141674395662E-16    22.7127454624211
#        29       8.88528576053352E-16    22.7127454713974
#        30       8.79144959398065E-16    22.7127454763703
#        31       8.78591890267517E-16    22.7127454791343
#        32       8.85325894647993E-16    22.7127454806740
#        33       8.70066182336828E-16    22.7127454815315
#        34       8.71454650086712E-16    22.7127454820131
#        35       8.73438751458077E-16    22.7127454822840
#        36       8.73176084610621E-16    22.7127454824348
#        37       8.74014063008852E-16    22.7127454825202
#        38       8.70732107664715E-16    22.7127454825684
#        39       8.75913366163154E-16    22.7127454825966
#        40       8.72533505015524E-16    22.7127454826116
#        41       8.74242759896121E-16    22.7127454826202
#        42       8.72798302131147E-16    22.7127454826253
#        43       8.69544222399476E-16    22.7127454826277
#        44       8.72412853147203E-16    22.7127454826297
#        45       8.70832361421081E-16    22.7127454826310
#        46       8.65100411049732E-16    22.7127454826310
#        47       8.71121215477551E-16    22.7127454826314
#        48       8.68659902454702E-16    22.7127454826317
#        49       8.71050899841891E-16    22.7127454826309
#        50       8.68033381747093E-16    22.7127454826322
#        51       8.70509439009337E-16    22.7127454826324
#        52       8.69970107944567E-16    22.7127454826313
#        53       8.70427229060342E-16    22.7127454826315
#        54       8.72820552427826E-16    22.7127454826309
#        55       8.67261407909339E-16    22.7127454826315
#        56       8.64712529017114E-16    22.7127454826316
#        57       8.70593212517842E-16    22.7127454826318
#        58       8.63832172567102E-16    22.7127454826314
#        59       8.63173241813457E-16    22.7127454826314
#        60       8.57938279425341E-16    22.7127454826318
#        61       8.58579909609132E-16    22.7127454826315
#        62       8.74404056648904E-16    22.7127454826318
#        63       8.67301065013901E-16    22.7127454826313
#        64       8.63384836444720E-16    22.7127454826317
#        65       8.63971438217499E-16    22.7127454826309
#        66       8.62447462291034E-16    22.7127454826319
#        67       8.63535715652259E-16    22.7127454826319
#        68       8.61325733558301E-16    22.7127454826321
#        69       8.55897709043410E-16    22.7127454826317
#        70       8.60213440084578E-16    22.7127454826326
#        71       8.66523049409848E-16    22.7127454826314
#        72       8.58560541980115E-16    22.7127454826322
#        73       8.67648121676997E-16    22.7127454826316
#        74       8.60096097573596E-16    22.7127454826318
#        75       8.59195042974869E-16    22.7127454826310
#  Benchmark completed
#  VERIFICATION SUCCESSFUL
#  Zeta is     2.2712745482631E+01
#  Error is    6.2567753977913E-16
#
#
#  CG Benchmark Completed.
#  Class           =                        B
#  Size            =                    75000
#  Iterations      =                       75
#  Time in seconds =                   130.08
#  Mop/s total     =                   420.57
#  Operation type  =           floating point
#  Verification    =               SUCCESSFUL
#  Version         =                    3.3.1
#  Compile date    =              23 May 2017
#
#  Compile options:
#     CC           = (none)
#     CLINK        = (none)
#     C_LIB        = -lm
#     C_INC        = -I../common
#     CFLAGS       = (none)
#     CLINKFLAGS   = (none)
#     RAND         = randdp
#
# --------------------------------------
#  Please send all errors/feedbacks to:
#  Center for Manycore Programming
#  cmp@aces.snu.ac.kr
#  http://aces.snu.ac.kr
# --------------------------------------
#
#
# ======== CPU profiling result (top down):
# Time(%)      Time  Name
#  100.00%   139.38s  main
#  94.55%   131.79s    conj_grad
#   5.41%     7.54s    makea
#   5.29%     7.38s      sparse
#   0.11%     160ms      sprnvc
#   0.08%     110ms        randlc
#
# ======== Data collected at 100Hz frequency

# %% [markdown]
# ### Quality Checking/Keeping a Record
#
# *After each step*, we will record the results from our benchmarking and correctness tests in a table like this one:
#
# |Step| Execution       | ExecutionTime (s)     | Speedup vs. 1 CPU Thread       | Correct? | Programming Time |
# |:--:| --------------- | ---------------------:| ------------------------------:|:--------:| -----------------|
# |1   | CPU 1 thread    | 130.08           |                                | Yes      |                |  |

# %% [markdown]
# Look mainly at conj_grad

# %% [markdown]
# ## Step 2 - Add Compute Directives

# %% [markdown]
# Things need to to before you add #pragma ...
#     1. Initiate the GPU
#         acc_init(acc_device_default);
#     2. Copy in variables GPU needed to run
#         #pragma acc data copyin(colidx[0:nz],a[0:nz], rowstr[0:na+1]) create(x[0:na+2],z[0:na+2], p[0:na+2],q[0:na+2], r[0:na+2])
#         {
#             ...
#          }
#
# #### Then find for loops and add '#pragma acc kernels loop' to the loop
# #### Add recuction() when it is applicable

# %%
# !cd ./NPB-acc/CG-step1/ && make clean && make CC=pgcc CLASS=B
# Out:
# rm -f *.x *.w2c.ptx *.o *.w2c.cu *.w2c.c *.w2c.h *.i *.spin *.B *.s *.t *~ ../common/*.o
# rm -f npbparams.h core
# make[1]: Entering directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# rm -f setparams setparams.h npbparams.h
# rm -f *~ *.o
# cc  -o setparams setparams.c
# make[1]: Leaving directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# ../sys/setparams cg B
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 cg.c
# main:
#     258, Generating copyin(a[:nz],colidx[:nz])
#          Generating create(p[:na+2],q[:na+2],r[:na+2])
#          Generating copyin(rowstr[:na+1])
#          Generating create(x[:na+2],z[:na+2])
#     269, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         269, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     275, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         275, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     304, Accelerator kernel generated
#          Generating Tesla code
#         304, Generating reduction(+:norm_temp2)
#         305, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     316, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         316, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     328, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         328, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     360, Accelerator kernel generated
#          Generating Tesla code
#         360, Generating reduction(+:norm_temp1,norm_temp2)
#         361, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     377, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         377, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
# conj_grad:
#     475, Generating present(a[:nz],colidx[:nz],p[:na+2],q[:na+2],r[:na+2],rowstr[:na+1],x[:na+2],z[:na+2])
#     485, Loop carried dependence of p->,r->,x->,z-> prevents parallelization
#          Complex loop carried dependence of q->,r->,x->,z-> prevents parallelization
#          Loop carried backward dependence of p->,r->,x->,z-> prevents vectorization
#          Accelerator kernel generated
#         485, #pragma acc loop seq
#     485, Accelerator scalar kernel generated
#     497, Accelerator kernel generated
#          Generating Tesla code
#         497, Generating reduction(+:rho)
#         498, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     539, Accelerator kernel generated
#          Generating Tesla code
#         542, #pragma acc loop gang /* blockIdx.x */
#         547, #pragma acc loop vector(128) /* threadIdx.x */
#              Generating reduction(+:sum)
#     547, Loop is parallelizable
#     560, Accelerator kernel generated
#          Generating Tesla code
#         563, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#              Generating reduction(+:d)
#     585, Loop carried dependence of q->,r->,z-> prevents parallelization
#          Complex loop carried dependence of p->,q->,z-> prevents parallelization
#          Loop carried backward dependence of q->,r->,z-> prevents vectorization
#          Accelerator kernel generated
#         585, #pragma acc loop seq
#     585, Accelerator scalar kernel generated
#     594, Accelerator kernel generated
#          Generating Tesla code
#         597, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#              Generating reduction(+:rho)
#     612, Loop carried dependence of p-> prevents parallelization
#          Complex loop carried dependence of r-> prevents parallelization
#          Loop carried backward dependence of p-> prevents vectorization
#          Accelerator kernel generated
#         612, #pragma acc loop seq
#     612, Accelerator scalar kernel generated
#     626, Accelerator kernel generated
#          Generating Tesla code
#         627, #pragma acc loop gang /* blockIdx.x */
#         632, #pragma acc loop vector(128) /* threadIdx.x */
#              Generating reduction(+:d)
#     632, Loop is parallelizable
#     645, Accelerator kernel generated
#          Generating Tesla code
#         645, Generating reduction(+:sum)
#         646, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
# cd ../common; pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium print_results.c
# cd ../common; pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium randdp.c
# cd ../common; pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium c_timers.c
# cd ../common; pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium  -o wtime.o ../common/wtime.c
# pgcc -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -o ./cg.B.x cg.o ../common/print_results.o ../common/randdp.o ../common/c_timers.o ../common/wtime.o -lm

# %% [markdown]
# If you get any error please check your work and try re-compilling.

# %%
# !ulimit -s unlimited && ./NPB-acc/CG-step1/cg.B.x
# Out:
#  NAS Parallel Benchmarks (NPB3.3-ACC-C) - CG Benchmark
#
#  Size:       75000
#  Iterations:    75
#
#  Initialization time =           4.634 seconds
#
#    iteration           ||r||                 zeta
#         1       8.88765256257298E-14    59.9994751578754
#         2       3.64772534035289E-16    21.7627846142538
#         3       3.80342263564589E-16    22.2876617043225
#         4       3.82893975525703E-16    22.5230738188352
#         5       3.84615658753603E-16    22.6275390653890
#         6       3.87812069871467E-16    22.6740259189537
#         7       3.83529848508281E-16    22.6949056826253
#         8       3.84959489734748E-16    22.7044023166871
#         9       3.87169229586280E-16    22.7087834345616
#        10       3.83418016642621E-16    22.7108351397172
#        11       3.79213562407113E-16    22.7118107121337
#        12       3.80483938355708E-16    22.7122816240973
#        13       3.79296490032389E-16    22.7125122663245
#        14       3.79382311109759E-16    22.7126268007598
#        15       3.78853316028659E-16    22.7126844161817
#        16       3.76680777071516E-16    22.7127137461758
#        17       3.76340455295173E-16    22.7127288401997
#        18       3.77745058513715E-16    22.7127366848297
#        19       3.74256724773564E-16    22.7127407981219
#        20       3.72193555405862E-16    22.7127429721363
#        21       3.72536206128753E-16    22.7127441294027
#        22       3.74023523465981E-16    22.7127447493899
#        23       3.69575443541184E-16    22.7127450834529
#        24       3.69716093455777E-16    22.7127452643880
#        25       3.68583032903271E-16    22.7127453628459
#        26       3.68456569385969E-16    22.7127454166513
#        27       3.66380775737790E-16    22.7127454461692
#        28       3.64659576563366E-16    22.7127454624205
#        29       3.63198072995797E-16    22.7127454713971
#        30       3.64026802918125E-16    22.7127454763704
#        31       3.64178039664442E-16    22.7127454791336
#        32       3.63533531060519E-16    22.7127454806729
#        33       3.61647441858143E-16    22.7127454815324
#        34       3.62304213016789E-16    22.7127454820135
#        35       3.57937595577455E-16    22.7127454822834
#        36       3.57549104312734E-16    22.7127454824351
#        37       3.58651527308052E-16    22.7127454825205
#        38       3.54825084361488E-16    22.7127454825687
#        39       3.56348614109263E-16    22.7127454825960
#        40       3.54995456142162E-16    22.7127454826114
#        41       3.55910977349389E-16    22.7127454826201
#        42       3.53358430345034E-16    22.7127454826251
#        43       3.52524572583154E-16    22.7127454826279
#        44       3.51509143954605E-16    22.7127454826295
#        45       3.50567758994197E-16    22.7127454826305
#        46       3.48657666945319E-16    22.7127454826310
#        47       3.49985962226014E-16    22.7127454826313
#        48       3.48051338531593E-16    22.7127454826315
#        49       3.47067333420127E-16    22.7127454826315
#        50       3.46368445996047E-16    22.7127454826316
#        51       3.43902652679847E-16    22.7127454826316
#        52       3.44295587907912E-16    22.7127454826317
#        53       3.42631819175149E-16    22.7127454826317
#        54       3.40120119636618E-16    22.7127454826317
#        55       3.42482318201073E-16    22.7127454826317
#        56       3.39187985195428E-16    22.7127454826317
#        57       3.39112188098223E-16    22.7127454826317
#        58       3.39783115360415E-16    22.7127454826317
#        59       3.39273240478111E-16    22.7127454826317
#        60       3.34029418071550E-16    22.7127454826317
#        61       3.33677175962244E-16    22.7127454826317
#        62       3.31551928288032E-16    22.7127454826317
#        63       3.33004721864249E-16    22.7127454826317
#        64       3.34616230727004E-16    22.7127454826317
#        65       3.32666324313222E-16    22.7127454826317
#        66       3.32143266269081E-16    22.7127454826317
#        67       3.30192998439080E-16    22.7127454826317
#        68       3.27126296486862E-16    22.7127454826317
#        69       3.23883420508324E-16    22.7127454826317
#        70       3.23753095192999E-16    22.7127454826317
#        71       3.24448297189587E-16    22.7127454826317
#        72       3.24013235379318E-16    22.7127454826317
#        73       3.24244970979641E-16    22.7127454826317
#        74       3.24462977027531E-16    22.7127454826317
#        75       3.22465631249201E-16    22.7127454826317
#  Benchmark completed
#  VERIFICATION SUCCESSFUL
#  Zeta is     2.2712745482632E+01
#  Error is    3.0658199449177E-14
#
#
#  CG Benchmark Completed.
#  Class           =                        B
#  Size            =                    75000
#  Iterations      =                       75
#  Time in seconds =                   108.42
#  Mop/s total     =                   504.60
#  Operation type  =           floating point
#  Verification    =               SUCCESSFUL
#  Version         =                    3.3.1
#  Compile date    =              23 May 2017
#
#  Compile options:
#     CC           = (none)
#     CLINK        = (none)
#     C_LIB        = -lm
#     C_INC        = -I../common
#     CFLAGS       = (none)
#     CLINKFLAGS   = (none)
#     RAND         = randdp
#
# --------------------------------------
#  Please send all errors/feedbacks to:
#  Center for Manycore Programming
#  cmp@aces.snu.ac.kr
#  http://aces.snu.ac.kr
# --------------------------------------
#
# conj calls=76, loop iter = 1900.

# %% [markdown]
# Let's record our results in the table:
#
# |Step| Execution    | Time(s)     | Speedup vs. 1 CPU Thread  | Correct? | Programming Time |
# | -- || ------------ | ----------- | ------------------------- | -------- | ---------------- |
# |1| CPU 1 thread |130.08      |                           |          | |
# |2| Add kernels directive  |108.42      | 1.21X           | Yes      | ||

# %% [markdown]
# ## Optimization
# Compiler use default setting of gang, worker and vector to run the benchmark.
# We can still adjust these values manully to let the program fit the device you have.
#
# For example:
# ```
# #pragma acc parallel num_gangs(end) num_workers(4) vector_length(32)
# {
# #pragma acc loop gang
#         for (j = 0; j < end; j++) {
#           tmp1 = rowstr[j];
#           tmp2 = rowstr[j+1];
#           sum = 0.0;
# #pragma acc loop worker vector reduction(+:sum)
#           for (k = tmp1; k < tmp2; k++) {
#
# ```

# %%
# !cd ./NPB-acc/CG-final/ && make clean && make CC=pgcc CLASS=B
# Out:
# rm -f *.x *.w2c.ptx *.o *.w2c.cu *.w2c.c *.w2c.h *.i *.spin *.B *.s *.t *~ ../common/*.o
# rm -f npbparams.h core
# make[1]: Entering directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# rm -f setparams setparams.h npbparams.h
# rm -f *~ *.o
# cc  -o setparams setparams.c
# make[1]: Leaving directory '/home/qichao/Desktop/notebooks-acc/NPB-acc/sys'
# ../sys/setparams cg B
# pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -DCRPL_COMP=0 cg.c
# main:
#     258, Generating copyin(a[:nz],colidx[:nz])
#          Generating create(p[:na+2],q[:na+2],r[:na+2])
#          Generating copyin(rowstr[:na+1])
#          Generating create(x[:na+2],z[:na+2])
#     273, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         273, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     283, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         283, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     318, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         318, #pragma acc loop gang, worker(4), vector(32) /* blockIdx.x threadIdx.y threadIdx.x */
#              Generating reduction(+:norm_temp2)
#     333, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         333, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     349, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         349, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     387, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         387, #pragma acc loop gang, worker(4), vector(32) /* blockIdx.x threadIdx.y threadIdx.x */
#              Generating reduction(+:norm_temp1,norm_temp2)
#     407, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         407, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
# conj_grad:
#     505, Generating present(a[:nz],colidx[:nz],p[:na+2],q[:na+2],r[:na+2],rowstr[:na+1],x[:na+2],z[:na+2])
#     519, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         519, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     537, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         537, #pragma acc loop gang, worker(4), vector(32) /* blockIdx.x threadIdx.y threadIdx.x */
#              Generating reduction(+:rho)
#     585, Loop carried dependence of q-> prevents parallelization
#          Complex loop carried dependence of a->,p-> prevents parallelization
#          Loop carried backward dependence of q-> prevents vectorization
#          Accelerator kernel generated
#          Generating Tesla code
#         585, #pragma acc loop seq
#         590, #pragma acc loop worker(4), vector(32) /* threadIdx.y threadIdx.
#              Generating reduction(+:sum)
#     590, Loop is parallelizable
#     610, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         610, #pragma acc loop gang, worker(4), vector(32) /* blockIdx.x threadIdx.y threadIdx.x */
#              Generating reduction(+:d)
#     636, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         636, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     652, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         652, #pragma acc loop gang, worker(4), vector(32) /* blockIdx.x threadIdx.y threadIdx.x */
#              Generating reduction(+:rho)
#     671, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         671, #pragma acc loop gang, vector(128) /* blockIdx.x threadIdx.x */
#     691, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         691, #pragma acc loop gang /* blockIdx.x */
#         696, #pragma acc loop worker(4), vector(32) /* threadIdx.y threadIdx.
#              Generating reduction(+:d)
#     696, Loop is parallelizable
#     718, Loop is parallelizable
#          Accelerator kernel generated
#          Generating Tesla code
#         718, #pragma acc loop gang, worker(4), vector(32) /* blockIdx.x threadIdx.y threadIdx.x */
#              Generating reduction(+:sum)
# cd ../common; pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium print_results.c
# cd ../common; pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium randdp.c
# cd ../common; pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium c_timers.c
# cd ../common; pgcc  -c -I../common -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium  -o wtime.o ../common/wtime.c
# pgcc -O3 -acc -ta=nvidia,cc35,cuda8.0  -Minfo=accel -mcmodel=medium -o ./cg.B.x cg.o ../common/print_results.o ../common/randdp.o ../common/c_timers.o ../common/wtime.o -lm

# %%
# !ulimit -s unlimited && ./NPB-acc/CG-final/cg.B.x
# Out:
#  NAS Parallel Benchmarks (NPB3.3-ACC-C) - CG Benchmark
#
#  Size:       75000
#  Iterations:    75
#
#  Initialization time =          10.713 seconds
#
#    iteration           ||r||                 zeta
#         1       8.88102088587189E-14    59.9994751578754
#         2       3.66238294280087E-16    21.7627846142538
#         3       3.79702708746571E-16    22.2876617043225
#         4       3.81606760478825E-16    22.5230738188352
#         5       3.84849469752605E-16    22.6275390653890
#         6       3.86542494879370E-16    22.6740259189537
#         7       3.83405242458680E-16    22.6949056826253
#         8       3.86641304912142E-16    22.7044023166871
#         9       3.82345464089509E-16    22.7087834345616
#        10       3.81857672275906E-16    22.7108351397172
#        11       3.80161276146272E-16    22.7118107121337
#        12       3.79588251304061E-16    22.7122816240973
#        13       3.78754892135336E-16    22.7125122663245
#        14       3.77214586387744E-16    22.7126268007598
#        15       3.77480545257807E-16    22.7126844161817
#        16       3.76215351554358E-16    22.7127137461758
#        17       3.78559340652619E-16    22.7127288401997
#        18       3.76652230685996E-16    22.7127366848297
#        19       3.74632134344327E-16    22.7127407981219
#        20       3.70891179462160E-16    22.7127429721363
#        21       3.73986091406024E-16    22.7127441294027
#        22       3.70931978998347E-16    22.7127447493899
#        23       3.71852081615776E-16    22.7127450834529
#        24       3.69769293773005E-16    22.7127452643880
#        25       3.71388560129575E-16    22.7127453628459
#        26       3.64845059168152E-16    22.7127454166513
#        27       3.67491103049496E-16    22.7127454461692
#        28       3.65044770372602E-16    22.7127454624205
#        29       3.63120330774848E-16    22.7127454713971
#        30       3.63358568451966E-16    22.7127454763704
#        31       3.63343152964658E-16    22.7127454791336
#        32       3.64005581789073E-16    22.7127454806729
#        33       3.61126370634268E-16    22.7127454815324
#        34       3.60712230725643E-16    22.7127454820135
#        35       3.58980814899198E-16    22.7127454822834
#        36       3.56488421492232E-16    22.7127454824351
#        37       3.55270385767151E-16    22.7127454825205
#        38       3.59499064338575E-16    22.7127454825687
#        39       3.54821109913685E-16    22.7127454825960
#        40       3.57783892439204E-16    22.7127454826114
#        41       3.53765027184958E-16    22.7127454826201
#        42       3.53702482198066E-16    22.7127454826251
#        43       3.52657764996465E-16    22.7127454826279
#        44       3.50466186779713E-16    22.7127454826295
#        45       3.48786883638434E-16    22.7127454826305
#        46       3.48245401309641E-16    22.7127454826310
#        47       3.50658825130836E-16    22.7127454826313
#        48       3.49243500372878E-16    22.7127454826315
#        49       3.46649722927715E-16    22.7127454826315
#        50       3.42506117000814E-16    22.7127454826316
#        51       3.47026082339220E-16    22.7127454826316
#        52       3.44144614046245E-16    22.7127454826317
#        53       3.42563827237222E-16    22.7127454826317
#        54       3.39876671230734E-16    22.7127454826317
#        55       3.42708195904373E-16    22.7127454826317
#        56       3.39287498675841E-16    22.7127454826317
#        57       3.40408949839401E-16    22.7127454826317
#        58       3.36575505505227E-16    22.7127454826317
#        59       3.37394353947198E-16    22.7127454826317
#        60       3.31954412777092E-16    22.7127454826317
#        61       3.33731536802551E-16    22.7127454826317
#        62       3.32900203113097E-16    22.7127454826317
#        63       3.32654726324970E-16    22.7127454826317
#        64       3.32777362064955E-16    22.7127454826317
#        65       3.31699988972361E-16    22.7127454826317
#        66       3.31156799455894E-16    22.7127454826317
#        67       3.28200549241141E-16    22.7127454826317
#        68       3.25772188307236E-16    22.7127454826317
#        69       3.23286591539004E-16    22.7127454826317
#        70       3.23105397177470E-16    22.7127454826317
#        71       3.24767966110490E-16    22.7127454826317
#        72       3.25223318037625E-16    22.7127454826317
#        73       3.23221945885405E-16    22.7127454826317
#        74       3.24205961237363E-16    22.7127454826317
#        75       3.22219419232768E-16    22.7127454826317
#  Benchmark completed
#  VERIFICATION SUCCESSFUL
#  Zeta is     2.2712745482632E+01
#  Error is    3.0658199449177E-14
#
#
#  CG Benchmark Completed.
#  Class           =                        B
#  Size            =                    75000
#  Iterations      =                       75
#  Time in seconds =                   569.84
#  Mop/s total     =                    96.01
#  Operation type  =           floating point
#  Verification    =               SUCCESSFUL
#  Version         =                    3.3.1
#  Compile date    =              23 May 2017
#
#  Compile options:
#     CC           = (none)
#     CLINK        = (none)
#     C_LIB        = -lm
#     C_INC        = -I../common
#     CFLAGS       = (none)
#     CLINKFLAGS   = (none)
#     RAND         = randdp
#
# --------------------------------------
#  Please send all errors/feedbacks to:
#  Center for Manycore Programming
#  cmp@aces.snu.ac.kr
#  http://aces.snu.ac.kr
# --------------------------------------
#
# conj calls=76, loop iter = 1900.

# %% [markdown]
# Let's record our results in the table:
#
# |Step| Execution    | Time(s)     | Speedup vs. 1 CPU Thread  | Correct? | Programming Time |
# | -- || ------------ | ----------- | ------------------------- | -------- | ---------------- |
# |1| CPU 1 thread |130.08      |                           |          | |
# |2| Add parallel directive  |108.42      | 1.21X           | Yes      | |
# |3| Slower  |569.84      | 0.22X           | Yes      | ||

# %% [markdown]
# ### Sergio's version is slower than sequential version
